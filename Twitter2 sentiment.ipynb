# %%
#import the python libraries
import pandas as pd
import sklearn
import nltk
import re
import numpy as np

# %%
#Read the data
import pandas as pd
from sklearn.model_selection import train_test_split
data1 = pd.read_csv('tweets.csv', header=0)
data1.head(10)
# Out:
#    id                                              tweet
# 0   1   @user when a father is dysfunctional and is s...
# 1   2  @user @user thanks for #lyft credit i can't us...
# 2   3                                bihday your majesty
# 3   4  #model   i love u take with u all the time in ...
# 4   5             factsguide: society now    #motivation
# 5   6  [2/2] huge fan fare and big talking before the...
# 6   7   @user camping tomorrow @user @user @user @use...
# 7   8  the next school year is the year for exams.ð...
# 8   9  we won!!! love the land!!! #allin #cavs #champ...
# 9  10   @user @user welcome here !  i'm   it's so #gr...

# %%
#Divide the data into training and test sets
y = data1.id
X = data1.drop('id', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
print("X_train:\n")
print(X_train.head())
print(X_train.shape)

print("\nX_test:\n")
print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#
#                                                    tweet
# 29451  tonight left me inspired to sta writing music ...
# 21856  @user @user i saw the rubik's cube in my prof'...
# 16970  mondaymorning  #understanding#sharelove#peace ...
# 11574  first s'mores of the season! #firepitfun #smor...
# 48589   @user i just had nothing to doð #hello   #...
# (39327, 1)
#
# X_test:
#
#                                                    tweet
# 12049   @user you don't know what you've got till it'...
# 42209  #coverreveal &amp; #giveaway for "hideaway" by...
# 8502          god always comes in the clutch! ðð½
# 35077  if i was you, i wanna be me i wanna be me.. ð...
# 19305  strawberry picking for the first time. #strawb...
# (9832, 1)

# %%
X_train.head(2)
# Out:
#                                                    tweet
# 29451  tonight left me inspired to sta writing music ...
# 21856  @user @user i saw the rubik's cube in my prof'...

# %%
#Remove the twitter handles
combi = X_train.append(X_test, ignore_index=True)

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
import numpy as np
combi['tidy_tweet'] = np.vectorize(remove_pattern)(combi['tweet'], "@[\w]*")

# %%
#Remove Punctuation, Numbers and Special Character
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")

# %%
#Remove words of length less than or equal to three
combi['tidy_tweet'] = combi['tidy_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

# %%
combi.head(100)
# Out:
#                                                 tweet  \
# 0   tonight left me inspired to sta writing music ...
# 1   @user @user i saw the rubik's cube in my prof'...
# 2   mondaymorning  #understanding#sharelove#peace ...
# 3   first s'mores of the season! #firepitfun #smor...
# 4    @user i just had nothing to doð #hello   #...
# 5   patiently waiting for @user to play @user #hyp...
# 6                      directly applicable to trump.
# 7   ya know guys, i was feeling stressed out after...
# 8   home cooked by ya boy #fit #gym #thejurney   #...
# 9    @user god is so good to me! chippies are in t...
# 10  sometimes a put different locations into my we...
# 11  red hill is going to be amazing! cannot wait! ...
# 12                                school just ended
# 13   @user #ripchristina #ripgrimmie we will miss ...
# 14  @user #bestsellers #inspiration   #golf  "neve...
